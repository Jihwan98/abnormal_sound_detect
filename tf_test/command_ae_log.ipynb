# %%
import os
import glob
import numpy as np
import librosa
import librosa.display

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler
from torchsummary import summary


import soundfile as sf

# %%
def make_data_list(path):
    data_list = list()

    folders = os.listdir(path)
    for folder in folders:
        p = os.path.join(path, folder)
        data_path = glob.glob(p + '/*.wav')
        data_list += data_path

    return data_list

# %%
data_list = make_data_list('data/mini_speech_commands')
len(data_list)
# Out:
# 8000

# %%
class AudioDataset(Dataset):
    def __init__(self, path, transform=None, sample_rate=16000):
        self.path = path
        self.data_list = self.make_data_list(path)
        
        self.transform = transform
        self.sr = sample_rate
        self.frame_length = 0.025
        self.frame_stride = 0.0126

    def __len__(self):
        return len(self.data_list)
    
    def __getitem__(self, idx):
        data_path = self.data_list[idx]
        data = self.log_Mel_S(data_path)
        data = np.expand_dims(data, axis=0)

        if self.transform is not None:
            data = self.transform(data)
        return data # (1, 40, 80)
    
    def log_Mel_S(self, wav_file):
        y, sr = librosa.load(wav_file, sr=self.sr)
        if len(y) < 16000:
            y = np.pad(y, (0,16000 - len(y)))
        elif len(y) > 16000:
            y = y[:16000]
        else:
            y = y

        input_nfft = int(round(sr * self.frame_length))
        input_stride = int(round(sr * self.frame_stride))

        s = librosa.feature.melspectrogram(y=y, n_mels=40, n_fft=input_nfft, hop_length=input_stride)
        s = librosa.power_to_db(s, ref=np.max)
        return s

    def make_data_list(self, path):
        data_list = list()

        folders = os.listdir(path)
        for folder in folders:
            p = os.path.join(path, folder)
            data_path = glob.glob(p + '/*.wav')
            data_list += data_path
        return data_list

# %%
dataset = AudioDataset(path='data/mini_speech_commands')
print(f'dataset.__len__() : {dataset.__len__()}')
dataset_indices = list(range(dataset.__len__()))
np.random.shuffle(dataset_indices)
val_split_index = int(np.floor(0.2 * dataset.__len__()))
train_idx, val_idx = dataset_indices[val_split_index:], dataset_indices[:val_split_index]

train_sampler = SubsetRandomSampler(train_idx)
val_sampler = SubsetRandomSampler(val_idx)

train_loader = DataLoader(dataset=dataset, batch_size=100, sampler=train_sampler, shuffle=False)
val_loader = DataLoader(dataset=dataset, batch_size=100, sampler=val_sampler, shuffle=False)
# Out:
# dataset.__len__() : 8000

# %%
class AE(nn.Module):
    def __init__(self, input_channel=1):
        super(AE, self).__init__()

        self.encoder = nn.Sequential(
            nn.Conv2d(input_channel, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )

        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.ConvTranspose2d(32, input_channel, kernel_size=4, stride=2, padding=1),
        )

    def forward(self, x):
        out = self.encoder(x)
        out = self.decoder(out)
        return out

    def get_codes(self, x):
        return self.encoder(x)

# %%
ae = AE()
if torch.cuda.is_available():
    ae.cuda()

# %%
ae
# Out:
# AE(
#   (encoder): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): ConvTranspose2d(32, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   )
# )

# %%
summary(ae, (1, 40, 80))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 40, 80]             320
#        BatchNorm2d-2           [-1, 32, 40, 80]              64
#               ReLU-3           [-1, 32, 40, 80]               0
#          MaxPool2d-4           [-1, 32, 20, 40]               0
#             Conv2d-5           [-1, 64, 20, 40]          18,496
#        BatchNorm2d-6           [-1, 64, 20, 40]             128
#               ReLU-7           [-1, 64, 20, 40]               0
#          MaxPool2d-8           [-1, 64, 10, 20]               0
#             Conv2d-9          [-1, 128, 10, 20]          73,856
#       BatchNorm2d-10          [-1, 128, 10, 20]             256
#              ReLU-11          [-1, 128, 10, 20]               0
#         MaxPool2d-12           [-1, 128, 5, 10]               0
#   ConvTranspose2d-13           [-1, 64, 10, 20]         131,136
#       BatchNorm2d-14           [-1, 64, 10, 20]             128
#              ReLU-15           [-1, 64, 10, 20]               0
#   ConvTranspose2d-16           [-1, 32, 20, 40]          32,800
#       BatchNorm2d-17           [-1, 32, 20, 40]              64
#              ReLU-18           [-1, 32, 20, 40]               0
#   ConvTranspose2d-19            [-1, 1, 40, 80]             513
# ================================================================
# Total params: 257,761
# Trainable params: 257,761
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.35
# Params size (MB): 0.98
# Estimated Total Size (MB): 6.34
# ----------------------------------------------------------------

# %%
def train(model, loss, optimizer, num_epochs, start_epoch=0, early_stopping=False):
    train_loss_arr = []
    test_loss_arr = []
    
    best_test_loss = 999999
    early_stop, early_stop_max = 0, 3

    for epoch in range(start_epoch, start_epoch + num_epochs):
        epoch_loss = 0.
        for batch_idx, data in enumerate(train_loader):
            data = data.cuda()
            optimizer.zero_grad()

            model.train()
            outputs = model(data)
            train_loss = loss(outputs, data)
            epoch_loss += train_loss.item()

            train_loss.backward()
            optimizer.step()

            if batch_idx % 10 == 0:
                print(f'Epoch : {epoch + 1} [{batch_idx * len(data)}/{len(train_idx)}({100. * batch_idx/len(train_idx) :.2f}%)]'\
                    +f'\tLoss : {train_loss.item() / len(data) :.4f}')
        
        train_loss_arr.append((epoch_loss / len(train_idx)))

        # validation

        model.eval()
        test_loss = 0.
        for data in val_loader:
            data = data.cuda()

            outputs = model(data)
            batch_loss = loss(outputs, data)
            test_loss += batch_loss.item()

        test_loss_arr.append((test_loss / len(val_idx)))

        if early_stopping:
            if best_test_loss > test_loss:
                best_test_loss = test_loss
                early_stop = 0
                print(f'Epoch [{epoch + 1}/{num_epochs}], Average Train Loss : {train_loss_arr[epoch-start_epoch] :.4f}, ' +\
                f'Average Test Loss : {test_loss_arr[epoch-start_epoch] :.4f}\n')
            else:
                early_stop += 1
                print(f'Epoch [{epoch + 1}/{num_epochs}], Average Train Loss : {train_loss_arr[epoch-start_epoch] :.4f}, ' +\
                f'Average Test Loss : {test_loss_arr[epoch-start_epoch] :.4f}\n')

            if early_stop >= early_stop_max:
                break
        else:
            print(f'Epoch [{epoch + 1}/{num_epochs}], Average Train Loss : {train_loss_arr[epoch-start_epoch] :.4f}, ' +\
            f'Average Test Loss : {test_loss_arr[epoch-start_epoch] :.4f}\n')
    return train_loss_arr, test_loss_arr

# %%
ae_loss = nn.MSELoss()
ae_optimizer = optim.Adam(ae.parameters())
avg_train_loss, avg_test_loss = train(ae, ae_loss, ae_optimizer, 50, start_epoch=0, early_stopping=True)
# Out:
# Epoch : 1 [0/6400(0.00%)]	Loss : 33.9793
# Epoch : 1 [1000/6400(0.16%)]	Loss : 31.4748
# Epoch : 1 [2000/6400(0.31%)]	Loss : 31.1260
# Epoch : 1 [3000/6400(0.47%)]	Loss : 29.3531
# Epoch : 1 [4000/6400(0.62%)]	Loss : 27.9684
# Epoch : 1 [5000/6400(0.78%)]	Loss : 27.7848
# Epoch : 1 [6000/6400(0.94%)]	Loss : 26.3145
# Epoch [1/50], Average Train Loss : 29.6398, Average Test Loss : 27.5567
#
# Epoch : 2 [0/6400(0.00%)]	Loss : 27.4376
# Epoch : 2 [1000/6400(0.16%)]	Loss : 26.1011
# Epoch : 2 [2000/6400(0.31%)]	Loss : 24.4080
# Epoch : 2 [3000/6400(0.47%)]	Loss : 25.2619
# Epoch : 2 [4000/6400(0.62%)]	Loss : 23.4418
# Epoch : 2 [5000/6400(0.78%)]	Loss : 21.7441
# Epoch : 2 [6000/6400(0.94%)]	Loss : 20.5289
# Epoch [2/50], Average Train Loss : 24.0481, Average Test Loss : 21.3557
#
# Epoch : 3 [0/6400(0.00%)]	Loss : 19.9455
# Epoch : 3 [1000/6400(0.16%)]	Loss : 19.8971
# Epoch : 3 [2000/6400(0.31%)]	Loss : 18.8191
# Epoch : 3 [3000/6400(0.47%)]	Loss : 16.0289
# Epoch : 3 [4000/6400(0.62%)]	Loss : 15.2791
# Epoch : 3 [5000/6400(0.78%)]	Loss : 16.4234
# Epoch : 3 [6000/6400(0.94%)]	Loss : 15.3624
# Epoch [3/50], Average Train Loss : 17.4578, Average Test Loss : 15.0158
#
# Epoch : 4 [0/6400(0.00%)]	Loss : 15.0616
# Epoch : 4 [1000/6400(0.16%)]	Loss : 13.6472
# Epoch : 4 [2000/6400(0.31%)]	Loss : 12.9790
# Epoch : 4 [3000/6400(0.47%)]	Loss : 11.5599
# Epoch : 4 [4000/6400(0.62%)]	Loss : 10.7697
# Epoch : 4 [5000/6400(0.78%)]	Loss : 10.5122
# Epoch : 4 [6000/6400(0.94%)]	Loss : 9.1098
# Epoch [4/50], Average Train Loss : 11.4331, Average Test Loss : 9.2537
#
# Epoch : 5 [0/6400(0.00%)]	Loss : 7.5138
# Epoch : 5 [1000/6400(0.16%)]	Loss : 7.4814
# Epoch : 5 [2000/6400(0.31%)]	Loss : 7.8304
# Epoch : 5 [3000/6400(0.47%)]	Loss : 7.1381
# Epoch : 5 [4000/6400(0.62%)]	Loss : 6.5927
# Epoch : 5 [5000/6400(0.78%)]	Loss : 5.0390
# Epoch : 5 [6000/6400(0.94%)]	Loss : 4.7624
# Epoch [5/50], Average Train Loss : 6.7023, Average Test Loss : 5.0804
#
# Epoch : 6 [0/6400(0.00%)]	Loss : 4.8369
# Epoch : 6 [1000/6400(0.16%)]	Loss : 4.8530
# Epoch : 6 [2000/6400(0.31%)]	Loss : 3.6986
# Epoch : 6 [3000/6400(0.47%)]	Loss : 3.6168
# Epoch : 6 [4000/6400(0.62%)]	Loss : 3.1268
# Epoch : 6 [5000/6400(0.78%)]	Loss : 2.8881
# Epoch : 6 [6000/6400(0.94%)]	Loss : 2.8898
# Epoch [6/50], Average Train Loss : 3.6260, Average Test Loss : 2.5382
#
# Epoch : 7 [0/6400(0.00%)]	Loss : 2.3755
# Epoch : 7 [1000/6400(0.16%)]	Loss : 2.5931
# Epoch : 7 [2000/6400(0.31%)]	Loss : 1.9030
# Epoch : 7 [3000/6400(0.47%)]	Loss : 1.7801
# Epoch : 7 [4000/6400(0.62%)]	Loss : 1.5803
# Epoch : 7 [5000/6400(0.78%)]	Loss : 1.5322
# Epoch : 7 [6000/6400(0.94%)]	Loss : 1.4205
# Epoch [7/50], Average Train Loss : 1.9243, Average Test Loss : 1.4279
#
# Epoch : 8 [0/6400(0.00%)]	Loss : 1.3133
# Epoch : 8 [1000/6400(0.16%)]	Loss : 1.3204
# Epoch : 8 [2000/6400(0.31%)]	Loss : 1.3371
# Epoch : 8 [3000/6400(0.47%)]	Loss : 1.1255
# Epoch : 8 [4000/6400(0.62%)]	Loss : 1.1285
# Epoch : 8 [5000/6400(0.78%)]	Loss : 0.8642
# Epoch : 8 [6000/6400(0.94%)]	Loss : 0.8674
# Epoch [8/50], Average Train Loss : 1.1080, Average Test Loss : 0.8553
#
# Epoch : 9 [0/6400(0.00%)]	Loss : 0.9501
# Epoch : 9 [1000/6400(0.16%)]	Loss : 0.8879
# Epoch : 9 [2000/6400(0.31%)]	Loss : 0.8002
# Epoch : 9 [3000/6400(0.47%)]	Loss : 0.7348
# Epoch : 9 [4000/6400(0.62%)]	Loss : 0.7186
# Epoch : 9 [5000/6400(0.78%)]	Loss : 0.5241
# Epoch : 9 [6000/6400(0.94%)]	Loss : 0.5084
# Epoch [9/50], Average Train Loss : 0.7159, Average Test Loss : 0.6095
#
# Epoch : 10 [0/6400(0.00%)]	Loss : 0.5673
# Epoch : 10 [1000/6400(0.16%)]	Loss : 0.5599
# Epoch : 10 [2000/6400(0.31%)]	Loss : 0.6195
# Epoch : 10 [3000/6400(0.47%)]	Loss : 0.5180
# Epoch : 10 [4000/6400(0.62%)]	Loss : 0.4475
# Epoch : 10 [5000/6400(0.78%)]	Loss : 0.4812
# Epoch : 10 [6000/6400(0.94%)]	Loss : 0.3926
# Epoch [10/50], Average Train Loss : 0.5221, Average Test Loss : 0.4075
#
# Epoch : 11 [0/6400(0.00%)]	Loss : 0.3701
# Epoch : 11 [1000/6400(0.16%)]	Loss : 0.3770
# Epoch : 11 [2000/6400(0.31%)]	Loss : 0.4076
# Epoch : 11 [3000/6400(0.47%)]	Loss : 0.3809
# Epoch : 11 [4000/6400(0.62%)]	Loss : 0.4930
# Epoch : 11 [5000/6400(0.78%)]	Loss : 0.3337
# Epoch : 11 [6000/6400(0.94%)]	Loss : 0.3058
# Epoch [11/50], Average Train Loss : 0.3837, Average Test Loss : 0.3280
#
# Epoch : 12 [0/6400(0.00%)]	Loss : 0.4016
# Epoch : 12 [1000/6400(0.16%)]	Loss : 0.3018
# Epoch : 12 [2000/6400(0.31%)]	Loss : 0.3016
# Epoch : 12 [3000/6400(0.47%)]	Loss : 0.2812
# Epoch : 12 [4000/6400(0.62%)]	Loss : 0.2811
# Epoch : 12 [5000/6400(0.78%)]	Loss : 0.3774
# Epoch : 12 [6000/6400(0.94%)]	Loss : 0.2687
# Epoch [12/50], Average Train Loss : 0.3044, Average Test Loss : 0.2899
#
# Epoch : 13 [0/6400(0.00%)]	Loss : 0.3125
# Epoch : 13 [1000/6400(0.16%)]	Loss : 0.2755
# Epoch : 13 [2000/6400(0.31%)]	Loss : 0.2690
# Epoch : 13 [3000/6400(0.47%)]	Loss : 0.2606
# Epoch : 13 [4000/6400(0.62%)]	Loss : 0.2488
# Epoch : 13 [5000/6400(0.78%)]	Loss : 0.2617
# Epoch : 13 [6000/6400(0.94%)]	Loss : 0.2511
# Epoch [13/50], Average Train Loss : 0.2612, Average Test Loss : 0.2413
#
# Epoch : 14 [0/6400(0.00%)]	Loss : 0.2405
# Epoch : 14 [1000/6400(0.16%)]	Loss : 0.2283
# Epoch : 14 [2000/6400(0.31%)]	Loss : 0.2580
# Epoch : 14 [3000/6400(0.47%)]	Loss : 0.2306
# Epoch : 14 [4000/6400(0.62%)]	Loss : 0.2539
# Epoch : 14 [5000/6400(0.78%)]	Loss : 0.2415
# Epoch : 14 [6000/6400(0.94%)]	Loss : 0.2405
# Epoch [14/50], Average Train Loss : 0.2401, Average Test Loss : 0.2226
#
# Epoch : 15 [0/6400(0.00%)]	Loss : 0.2072
# Epoch : 15 [1000/6400(0.16%)]	Loss : 0.2153
# Epoch : 15 [2000/6400(0.31%)]	Loss : 0.2377
# Epoch : 15 [3000/6400(0.47%)]	Loss : 0.2751
# Epoch : 15 [4000/6400(0.62%)]	Loss : 0.2594
# Epoch : 15 [5000/6400(0.78%)]	Loss : 0.2072
# Epoch : 15 [6000/6400(0.94%)]	Loss : 0.1930
# Epoch [15/50], Average Train Loss : 0.2233, Average Test Loss : 0.2023
#
# Epoch : 16 [0/6400(0.00%)]	Loss : 0.1877
# Epoch : 16 [1000/6400(0.16%)]	Loss : 0.2204
# Epoch : 16 [2000/6400(0.31%)]	Loss : 0.2030
# Epoch : 16 [3000/6400(0.47%)]	Loss : 0.2135
# Epoch : 16 [4000/6400(0.62%)]	Loss : 0.1981
# Epoch : 16 [5000/6400(0.78%)]	Loss : 0.2009
# Epoch : 16 [6000/6400(0.94%)]	Loss : 0.1859
# Epoch [16/50], Average Train Loss : 0.2040, Average Test Loss : 0.1906
#
# Epoch : 17 [0/6400(0.00%)]	Loss : 0.1904
# Epoch : 17 [1000/6400(0.16%)]	Loss : 0.1792
# Epoch : 17 [2000/6400(0.31%)]	Loss : 0.1737
# Epoch : 17 [3000/6400(0.47%)]	Loss : 0.1862
# Epoch : 17 [4000/6400(0.62%)]	Loss : 0.1791
# Epoch : 17 [5000/6400(0.78%)]	Loss : 0.1810
# Epoch : 17 [6000/6400(0.94%)]	Loss : 0.1954
# Epoch [17/50], Average Train Loss : 0.1870, Average Test Loss : 0.1770
#
# Epoch : 18 [0/6400(0.00%)]	Loss : 0.1793
# Epoch : 18 [1000/6400(0.16%)]	Loss : 0.1971
# Epoch : 18 [2000/6400(0.31%)]	Loss : 0.2086
# Epoch : 18 [3000/6400(0.47%)]	Loss : 0.1796
# Epoch : 18 [4000/6400(0.62%)]	Loss : 0.2234
# Epoch : 18 [5000/6400(0.78%)]	Loss : 0.1651
# Epoch : 18 [6000/6400(0.94%)]	Loss : 0.1629
# Epoch [18/50], Average Train Loss : 0.1799, Average Test Loss : 0.1644
#
# Epoch : 19 [0/6400(0.00%)]	Loss : 0.1568
# Epoch : 19 [1000/6400(0.16%)]	Loss : 0.1998
# Epoch : 19 [2000/6400(0.31%)]	Loss : 0.1813
# Epoch : 19 [3000/6400(0.47%)]	Loss : 0.1724
# Epoch : 19 [4000/6400(0.62%)]	Loss : 0.1916
# Epoch : 19 [5000/6400(0.78%)]	Loss : 0.1918
# Epoch : 19 [6000/6400(0.94%)]	Loss : 0.1682
# Epoch [19/50], Average Train Loss : 0.1741, Average Test Loss : 0.1632
#
# Epoch : 20 [0/6400(0.00%)]	Loss : 0.1604
# Epoch : 20 [1000/6400(0.16%)]	Loss : 0.1701
# Epoch : 20 [2000/6400(0.31%)]	Loss : 0.1625
# Epoch : 20 [3000/6400(0.47%)]	Loss : 0.1595
# Epoch : 20 [4000/6400(0.62%)]	Loss : 0.1536
# Epoch : 20 [5000/6400(0.78%)]	Loss : 0.1481
# Epoch : 20 [6000/6400(0.94%)]	Loss : 0.1800
# Epoch [20/50], Average Train Loss : 0.1694, Average Test Loss : 0.1553
#
# Epoch : 21 [0/6400(0.00%)]	Loss : 0.1617
# Epoch : 21 [1000/6400(0.16%)]	Loss : 0.1818
# Epoch : 21 [2000/6400(0.31%)]	Loss : 0.1755
# Epoch : 21 [3000/6400(0.47%)]	Loss : 0.1639
# Epoch : 21 [4000/6400(0.62%)]	Loss : 0.1562
# Epoch : 21 [5000/6400(0.78%)]	Loss : 0.1490
# Epoch : 21 [6000/6400(0.94%)]	Loss : 0.1784
# Epoch [21/50], Average Train Loss : 0.1615, Average Test Loss : 0.1501
#
# Epoch : 22 [0/6400(0.00%)]	Loss : 0.1487
# Epoch : 22 [1000/6400(0.16%)]	Loss : 0.1871
# Epoch : 22 [2000/6400(0.31%)]	Loss : 0.1533
# Epoch : 22 [3000/6400(0.47%)]	Loss : 0.1525
# Epoch : 22 [4000/6400(0.62%)]	Loss : 0.1796
# Epoch : 22 [5000/6400(0.78%)]	Loss : 0.1523
# Epoch : 22 [6000/6400(0.94%)]	Loss : 0.1823
# Epoch [22/50], Average Train Loss : 0.1634, Average Test Loss : 0.1575
#
# Epoch : 23 [0/6400(0.00%)]	Loss : 0.2097
# Epoch : 23 [1000/6400(0.16%)]	Loss : 0.2049
# Epoch : 23 [2000/6400(0.31%)]	Loss : 0.1431
# Epoch : 23 [3000/6400(0.47%)]	Loss : 0.1476
# Epoch : 23 [4000/6400(0.62%)]	Loss : 0.1881
# Epoch : 23 [5000/6400(0.78%)]	Loss : 0.1675
# Epoch : 23 [6000/6400(0.94%)]	Loss : 0.1459
# Epoch [23/50], Average Train Loss : 0.1567, Average Test Loss : 0.1436
#
# Epoch : 24 [0/6400(0.00%)]	Loss : 0.1454
# Epoch : 24 [1000/6400(0.16%)]	Loss : 0.1464
# Epoch : 24 [2000/6400(0.31%)]	Loss : 0.1422
# Epoch : 24 [3000/6400(0.47%)]	Loss : 0.1506
# Epoch : 24 [4000/6400(0.62%)]	Loss : 0.1609
# Epoch : 24 [5000/6400(0.78%)]	Loss : 0.1470
# Epoch : 24 [6000/6400(0.94%)]	Loss : 0.1439
# Epoch [24/50], Average Train Loss : 0.1484, Average Test Loss : 0.1384
#
# Epoch : 25 [0/6400(0.00%)]	Loss : 0.1369
# Epoch : 25 [1000/6400(0.16%)]	Loss : 0.1395
# Epoch : 25 [2000/6400(0.31%)]	Loss : 0.1323
# Epoch : 25 [3000/6400(0.47%)]	Loss : 0.1713
# Epoch : 25 [4000/6400(0.62%)]	Loss : 0.1503
# Epoch : 25 [5000/6400(0.78%)]	Loss : 0.1354
# Epoch : 25 [6000/6400(0.94%)]	Loss : 0.1943
# Epoch [25/50], Average Train Loss : 0.1555, Average Test Loss : 0.1488
#
# Epoch : 26 [0/6400(0.00%)]	Loss : 0.1532
# Epoch : 26 [1000/6400(0.16%)]	Loss : 0.1555
# Epoch : 26 [2000/6400(0.31%)]	Loss : 0.1631
# Epoch : 26 [3000/6400(0.47%)]	Loss : 0.1405
# Epoch : 26 [4000/6400(0.62%)]	Loss : 0.1826
# Epoch : 26 [5000/6400(0.78%)]	Loss : 0.1412
# Epoch : 26 [6000/6400(0.94%)]	Loss : 0.1402
# Epoch [26/50], Average Train Loss : 0.1491, Average Test Loss : 0.1365
#
# Epoch : 27 [0/6400(0.00%)]	Loss : 0.1498
# Epoch : 27 [1000/6400(0.16%)]	Loss : 0.1591
# Epoch : 27 [2000/6400(0.31%)]	Loss : 0.1466
# Epoch : 27 [3000/6400(0.47%)]	Loss : 0.1405
# Epoch : 27 [4000/6400(0.62%)]	Loss : 0.1602
# Epoch : 27 [5000/6400(0.78%)]	Loss : 0.1409
# Epoch : 27 [6000/6400(0.94%)]	Loss : 0.1736
# Epoch [27/50], Average Train Loss : 0.1465, Average Test Loss : 0.1390
#
# Epoch : 28 [0/6400(0.00%)]	Loss : 0.1366
# Epoch : 28 [1000/6400(0.16%)]	Loss : 0.1609
# Epoch : 28 [2000/6400(0.31%)]	Loss : 0.1421
# Epoch : 28 [3000/6400(0.47%)]	Loss : 0.1445
# Epoch : 28 [4000/6400(0.62%)]	Loss : 0.1339
# Epoch : 28 [5000/6400(0.78%)]	Loss : 0.1906
# Epoch : 28 [6000/6400(0.94%)]	Loss : 0.1653
# Epoch [28/50], Average Train Loss : 0.1488, Average Test Loss : 0.1376
#
# Epoch : 29 [0/6400(0.00%)]	Loss : 0.1434
# Epoch : 29 [1000/6400(0.16%)]	Loss : 0.1348
# Epoch : 29 [2000/6400(0.31%)]	Loss : 0.1383
# Epoch : 29 [3000/6400(0.47%)]	Loss : 0.1301
# Epoch : 29 [4000/6400(0.62%)]	Loss : 0.1540
# Epoch : 29 [5000/6400(0.78%)]	Loss : 0.1255
# Epoch : 29 [6000/6400(0.94%)]	Loss : 0.1389
# Epoch [29/50], Average Train Loss : 0.1368, Average Test Loss : 0.1441

# %%
import matplotlib.pyplot as plt
plt.plot(avg_train_loss, label='train')
plt.plot(avg_test_loss, label='test')
plt.legend()

plt.show()

# %%
def plot_mel(s):
    sr = 16000
    frame_stride = 0.0126
    input_stride = int(round(sr*frame_stride))
    librosa.display.specshow(s, sr=16000, hop_length=input_stride,\
        y_axis='mel', x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel Spectogram')
    plt.tight_layout()
    plt.show()

# %%
def plot_mel_2(s1, s2):
    sr = 16000
    frame_stride = 0.0126
    input_stride = int(round(sr*frame_stride))

    plt.figure(figsize=(20,4))
    plt.subplot(1,2,1)
    librosa.display.specshow(s1, sr=16000, hop_length=input_stride,\
        y_axis='mel', x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Original')
    plt.tight_layout()

    plt.subplot(1,2,2)
    librosa.display.specshow(s2, sr=16000, hop_length=input_stride,\
        y_axis='mel', x_axis='time')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Output')
    plt.tight_layout()

    plt.show()

# %%
for data in train_loader:
    a = data[0]
    print(a.shape)
    break
# Out:
# torch.Size([1, 40, 80])

# %%
for data in train_loader:
    for i in range(2):
        a = data[i].cpu().detach().numpy()
        b = ae(torch.Tensor(a.reshape(1,1,40,80)).cuda())
        plot_mel_2(a.squeeze(), b.cpu().detach().numpy().squeeze())
    break

# %%
def log_Mel_S(wav_file):
    sr = 16000
    frame_length = 0.025
    frame_stride = 0.0126 
    y, sr = librosa.load(wav_file, sr=sr)
    if len(y) < 16000:
        y = np.pad(y, (0,16000 - len(y)))
    elif len(y) > 16000:
        y = y[:16000]
    else:
        y = y

    input_nfft = int(round(sr * frame_length))
    input_stride = int(round(sr * frame_stride))

    s = librosa.feature.melspectrogram(y=y, n_mels=40, n_fft=input_nfft, hop_length=input_stride)
    s = librosa.power_to_db(s, ref=np.max)
    return s

def log_mel_to_audio(log_mel):
    sr = 16000
    frame_length = 0.025
    frame_stride = 0.0126 
    
    mel = librosa.db_to_power(log_mel)
    
    input_nfft = int(round(sr*frame_length))
    input_stride = int(round(sr*frame_stride))
    return librosa.feature.inverse.mel_to_audio(mel, sr=sr, n_fft=input_nfft, hop_length=input_stride)

# %%
data_path = 'data/mini_speech_commands/down/0ab3b47d_nohash_0.wav'
s = log_Mel_S(data_path)
out = ae(torch.Tensor(s.reshape(1,1,40,80)).cuda())
out = out.cpu().detach().numpy().squeeze()
plot_mel_2(s, out)

orig = log_mel_to_audio(s)
output = log_mel_to_audio(out)

sf.write('orig.wav', orig, 16000)
sf.write('output.wav', output, 16000)
